# %% [markdown]
# <a href="https://colab.research.google.com/github/ajay47847/pcg_classification/blob/main/ReSampNormAbn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from scipy.signal import resample

# Load the audio files
sample_rate1, audio_data1 = wavfile.read('/content/f0096.wav')
sample_rate2, audio_data2 = wavfile.read('/content/f0015.wav')

# Extract 2.5 seconds of audio
duration = 2.5
num_samples1 = int(duration * sample_rate1)
num_samples2 = int(duration * sample_rate2)
audio_data1 = audio_data1[:num_samples1]
audio_data2 = audio_data2[:num_samples2]

# Resample the audio to 1000 Hz
resample_rate = 1000
num_resampled_samples1 = int(duration * resample_rate)
num_resampled_samples2 = int(duration * resample_rate)
audio_data1_resampled = resample(audio_data1, num_resampled_samples1)
audio_data2_resampled = resample(audio_data2, num_resampled_samples2)
print('The sampling rate of this signal1: ', resample_rate)
print('The sampling rate of this signal2: ', resample_rate)


# Create time arrays for resampled data
time1_resampled = np.arange(0, duration, 1 / resample_rate)
time2_resampled = np.arange(0, duration, 1 / resample_rate)

plt.figure(figsize=(14, 6))

plt.subplot(2, 1, 1)
plt.plot(time1_resampled, audio_data1_resampled)
plt.title('Audio Waveform [Normal]')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.grid(True)

plt.subplot(2, 1, 2)
plt.plot(time2_resampled, audio_data2_resampled)
plt.title('Audio Waveform [Abnormal]')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# The sampling rate of this signal1:  1000
# The sampling rate of this signal2:  1000
